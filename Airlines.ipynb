# %%
# importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
fightpred = pd.read_csv(r"C:\Users\kirti\OneDrive\Desktop\Python Excel files\Flight_Booking\Flight_Booking.csv")

# %%
fightpred
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %%
fightpred.drop('Unnamed: 0', inplace = True, axis = 1)

# %%
fightpred.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
fightpred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  object
#  1   flight            300153 non-null  object
#  2   source_city       300153 non-null  object
#  3   departure_time    300153 non-null  object
#  4   stops             300153 non-null  object
#  5   arrival_time      300153 non-null  object
#  6   destination_city  300153 non-null  object
#  7   class             300153 non-null  object
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 25.2+ MB

# %%
# getting an overview of total rows and columns
fightpred.shape
# Out:
# (300153, 11)

# %%
## getting summary of dataset
round(fightpred.describe(include = 'all'))
# Out:
#         airline  flight source_city departure_time   stops arrival_time  \
# count    300153  300153      300153         300153  300153       300153
# unique        6    1561           6              6       3            6
# top     Vistara  UK-706       Delhi        Morning     one        Night
# freq     127859    3235       61343          71146  250863        91538
# mean        NaN     NaN         NaN            NaN     NaN          NaN
# std         NaN     NaN         NaN            NaN     NaN          NaN
# min         NaN     NaN         NaN            NaN     NaN          NaN
# 25%         NaN     NaN         NaN            NaN     NaN          NaN
# 50%         NaN     NaN         NaN            NaN     NaN          NaN
# 75%         NaN     NaN         NaN            NaN     NaN          NaN
# max         NaN     NaN         NaN            NaN     NaN          NaN
#
#        destination_city    class  duration  days_left     price
# ...

# %% [markdown]
# ## Conclusion:
# 1) There are no missing values in the data.
# 2) Airline 'Vistara' and flight 'UK-706' has occured maximum number of times.
# 3) Most Common source-city is Delhi and destination city is Mumbai .
# 4) Prefrence for Economy class is the highest.
# 5) Average duration of the journey is 12 hours.
# 6) Range of the price of the air tickets is 1,21,966.
# 7) Average price of the tickets is around 20890.

# %%
## Confirming Missing Values
fightpred.isna().sum()
# Out:
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
## Checking for Duplicates
fightpred.duplicated().sum()
# Out:
# 0

# %%
## Getting unique values of the dataset
for column in fightpred.columns:
    
        print(column.upper(), ':', fightpred[column].nunique())
        print(fightpred[column].value_counts().sort_values())
        print('\n')
# Out:
# AIRLINE : 6
# airline
# SpiceJet       9011
# AirAsia       16098
# GO_FIRST      23173
# Indigo        43120
# Air_India     80892
# Vistara      127859
# Name: count, dtype: int64
#
#
# FLIGHT : 1561
# flight
# G8-107        1
# 6E-2914       1
# SG-8480       1
# SG-1058       1
# SG-8106       1
#            ...
# UK-822     2468
# UK-836     2542
# UK-720     2650
# UK-772     2741
# UK-706     3235
# Name: count, Length: 1561, dtype: int64
#
#
# SOURCE_CITY : 6
# source_city
# Chennai      38700
# Hyderabad    40806
# Kolkata      46347
# Bangalore    52061
# Mumbai       60896
# Delhi        61343
# Name: count, dtype: int64
#
#
# DEPARTURE_TIME : 6
# departure_time
# Late_Night        1306
# Afternoon        47794
# Night            48015
# Evening          65102
# Early_Morning    66790
# Morning          71146
# Name: count, dtype: int64
#
#
# STOPS : 3
# stops
# two_or_more     13286
# zero            36004
# one            250863
# Name: count, dtype: int64
#
#
# ...

# %% [markdown]
# ## Univariate Analysis

# %%
##   Univariate Analysis:  Airlines
plt.figure(figsize= (20,7))
sns.countplot(data = fightpred, x = 'airline', palette="flare", )
plt.title('Airlines Distribution')
plt.xlabel('Airlines')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Conclusion: Vistara is mostly preferred among customers

# %%
fightpred.columns
# Out:
# Index(['airline', 'flight', 'source_city', 'departure_time', 'stops',
#        'arrival_time', 'destination_city', 'class', 'duration', 'days_left',
#        'price'],
#       dtype='object')

# %%
## Univariate Analysis for object datatype
for col in fightpred.columns:
    if fightpred[col].dtype == 'object':
        plt.figure(figsize= (20,7))
        sns.countplot(data = fightpred, x = col , palette="viridis", )
        plt.title('Airlines Distribution')
        plt.xlabel('Airlines')
        plt.ylabel('Frequency')

# %%
## Histogram for price
plt.figure(figsize= (12,6))
sns.histplot(fightpred['price'], kde= True, bins = 30)
plt.title('Distribution of flight Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt

# %% [markdown]
# ## Conclusion
# 1) It is seen that distribution of prices are positively skewed.

# %%
##  Bivariate Analysis:  Airlines-Price Distribution
plt.figure(figsize= (12,6))
sns.barplot(data = fightpred, x = 'airline', y ='price', palette="Set2" )
plt.title('Airline-Price Distribution')
plt.xlabel('Airlines')
plt.ylabel('FlightPrice')
# Out:
# Text(0, 0.5, 'FlightPrice')

# %% [markdown]
# ## Conclusion:
#
# Vistara flights are the costliest followed by Air_India

# %%
##   Multivariate Analysis:  Class-Price Distribution
plt.figure(figsize= (12,6))
sns.barplot(data = fightpred, x = 'class', y ='price', hue = 'airline', palette="pastel")
plt.title('Class-Price Distribution')
plt.xlabel('Class')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ## Conclusion
# 1) Vistara is the costliest in Business as well as Economy class followed by Airindia
# 2) AirAsia is the cheapest amongst the Economy Class available.

# %%
##   Multivariate Analysis:  Price Variation of Airlines with Stops
plt.figure(figsize= (12,6))
sns.lineplot(data=fightpred, x="airline", y="price", color = 'Green', hue ='stops', dashes= True)
plt.title('Airline Vs Price')
plt.xlabel('Airlines')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ## Conclusion
# There is a variation in Price with Different Airlines

# %%
## checking the unique values of price
fightpred['price'].value_counts().sort_values(ascending = False)
# Out:
# price
# 54608     1445
# 2339      1442
# 54684     1390
# 60978     1383
# 60508     1230
#           ...
# 105168       1
# 89953        1
# 20403        1
# 17464        1
# 7533         1
# Name: count, Length: 12157, dtype: int64

# %%
## Checking relation between Days left for Departure and Ticket Price
plt.figure(figsize= (12,6))
sns.lineplot(data=fightpred, x="days_left", y="price", hue = 'airline')
plt.title('Days left for Departure Vs Ticket Price')
plt.xlabel('Days left for Departure')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## Conclusion
# Here we have noticed that for all the airlines the ticket price is increased as the days left for departure decreases.

# %%
Departure_Price = pd.pivot_table(data = fightpred , index = ["departure_time"],columns = "airline",aggfunc = "mean",values = "price")
Departure_Price
# Out:
# airline             AirAsia     Air_India     GO_FIRST       Indigo  \
# departure_time
# Afternoon       4342.759584  23789.167617  5482.280858  5666.364943
# Early_Morning   4527.002979  23346.060200  5659.073079  5203.600440
# Evening         4058.764561  23366.248792  5604.052610  4813.684870
# Late_Night      4183.125874  26479.151203  4806.554795  4317.195592
# Morning         4132.566865  21747.785007  6500.995870  5904.384736
# Night           3343.718239  25968.716429  4861.946995  4324.235380
#
# airline            SpiceJet       Vistara
# departure_time
# Afternoon       7720.376362  28656.015157
# Early_Morning   5813.590543  30021.534979
# Evening         5720.595273  31081.607169
# Late_Night              NaN           NaN
# Morning         6894.052008  30608.385707
# Night           5533.119481  31029.404964

# %%
fightpred[(fightpred['airline' ]== 'SpiceJet') & (fightpred['airline' ]== 'Vistara')& (fightpred['departure_time'] == 'Late_Night')]
# Out:
# Empty DataFrame
# Columns: [airline, flight, source_city, departure_time, stops, arrival_time, destination_city, class, duration, days_left, price]
# Index: []

# %%
## Checking relationship bewteen departure time and Prices
plt.figure(figsize= (12,6))
sns.lineplot(data=fightpred, x="departure_time", y="price", hue= 'airline',color = 'Purple', dashes= True)
plt.title('Departure_time Vs Ticket Price')
plt.xlabel('departure_time')
plt.ylabel('Price')
plt.show()

# %%
Departure_Price.plot.bar(stacked = True,figsize = (20,7))
# Out:
# <Axes: xlabel='departure_time'>

# %% [markdown]
# ## Conclusion:
# 1) Average Airlines prices for most of the airlines are higher in Morning and cheaper at night.
# 2) AirIndia Flightis an exception with prices being low in Morning and High in Latenight.
# 3) Vistara afternoon Flight prices are cheaper and a little higher in evening and then almost contant afterwards.
# 4) There are are no late_night flights available for Vistara and Spicejet

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data =fightpred, x='duration', y='price', alpha=0.5)
plt.title('Price vs. Duration of Flight')
plt.xlabel('Flight Duration (hours)')
plt.ylabel('Ticket Price ($)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.jointplot(x='duration', y='price', data=fightpred, kind='reg', scatter_kws={'alpha':0.3})
plt.suptitle('Price vs. Duration with Marginal Distributions')
plt.show()

# %%
fightpred.duration.max()
# Out:
# 49.83

# %%
fightpred.duration.min()
# Out:
# 0.83

# %%
fightpred
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# ...

# %%
plt.figure(figsize= (12,6))
sns.lineplot(data=fightpred, x="duration", y="price", markers=True, dashes=False)
plt.title('Days left for Departure Vs Ticket Price')
plt.xlabel('Duration')
plt.ylabel('Price')
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize= (12,6))
sns.lineplot(data=fightpred, x="days_left", y="price", hue = 'source_city', ax= ax[0])
sns.lineplot(data=fightpred, x="days_left", y="price", hue = 'destination_city', ax = ax[1])
plt.xlabel('days_left for departure')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
fightpred['airline'] = le.fit_transform(fightpred['airline'])
fightpred['source_city'] = le.fit_transform(fightpred['source_city'])
fightpred['stops'] = le.fit_transform(fightpred['stops'])
fightpred['departure_time'] = le.fit_transform(fightpred['departure_time'])
fightpred['destination_city'] = le.fit_transform(fightpred['destination_city'])
fightpred['arrival_time'] = le.fit_transform(fightpred['arrival_time'])
fightpred['class'] = le.fit_transform(fightpred['class'])

fightpred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  int32
#  1   flight            300153 non-null  object
#  2   source_city       300153 non-null  int32
#  3   departure_time    300153 non-null  int32
#  4   stops             300153 non-null  int32
#  5   arrival_time      300153 non-null  int32
#  6   destination_city  300153 non-null  int32
#  7   class             300153 non-null  int32
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
# dtypes: float64(1), int32(7), int64(2), object(1)
# memory usage: 17.2+ MB

# %%
fightpred.drop('flight',  axis = 1, inplace = True)

# %% [markdown]
# ## Feature Selection

# %%
plt.figure(figsize = (10,10))
sns.heatmap(fightpred.corr(),annot= True,cmap = "coolwarm")
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x = fightpred.drop('price' , axis = 1)

# %%
x
# Out:
#         airline  source_city  departure_time  stops  arrival_time  \
# 0             4            2               2      2             5
# 1             4            2               1      2             4
# 2             0            2               1      2             1
# 3             5            2               4      2             0
# 4             5            2               4      2             4
# ...         ...          ...             ...    ...           ...
# 300148        5            1               4      0             2
# 300149        5            1               0      0             5
# 300150        5            1               1      0             5
# 300151        5            1               1      0             2
# 300152        5            1               4      0             2
#
#         destination_city  class  duration  days_left
# 0                      5      1      2.17          1
# 1                      5      1      2.33          1
# ...

# %%
y = fightpred['price']

# %%
y
# Out:
# 0          5953
# 1          5953
# 2          5956
# 3          5955
# 4          5955
#           ...
# 300148    69265
# 300149    77105
# 300150    79099
# 300151    81585
# 300152    81585
# Name: price, Length: 300153, dtype: int64

# %%
vif_data = pd. DataFrame()
vif_data['Columns']= x.columns
vif_data['VIF_values']= [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif_data
# Out:
#             Columns  VIF_values
# 0           airline    3.393124
# 1       source_city    2.927766
# 2    departure_time    2.779427
# 3             stops    1.426614
# 4      arrival_time    3.684550
# 5  destination_city    2.885337
# 6             class    2.849370
# 7          duration    4.113876
# 8         days_left    3.976790

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train,y_test = train_test_split(x,y, train_size=0.8, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr= LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
difference= pd.DataFrame(np.c_[y_test,y_pred],columns= ["Actual Values", "Pred Values"])

# %%
difference
# Out:
#        Actual Values   Pred Values
# 0             7366.0   4585.880510
# 1            64831.0  52842.077073
# 2             6195.0   7877.980184
# 3            60160.0  56120.138579
# 4             6578.0   6663.204177
# ...              ...           ...
# 60026         5026.0   5829.230618
# 60027         3001.0    539.222230
# 60028         6734.0   5848.965500
# 60029         5082.0  -1498.061918
# 60030        66465.0  58762.406345
#
# [60031 rows x 2 columns]

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.904554350718816

# %%
from sklearn import metrics

# %%
mean_abs_error= metrics.mean_absolute_error(y_test, y_pred)
mean_abs_error
# Out:
# 4624.994868016875

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.4353581089683257

# %%
mean_sq_error= metrics.mean_squared_error(y_test, y_pred)
mean_sq_error
# Out:
# 49200540.293721996

# %%
root_mean_sq_error=np.sqrt(metrics.mean_squared_error(y_test, y_pred))
root_mean_sq_error
# Out:
# 7014.3096804833185

# %%
sns.distplot(y_test,label = 'Actual')
sns.distplot(y_pred, label = 'Predicted')
plt.legend()
